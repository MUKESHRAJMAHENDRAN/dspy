# %%
#!uv pip install --upgrade "mlflow>=3.1"

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("Tracing Quickstart")
# Out:
# 2025/11/28 19:20:56 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/11/28 19:20:56 INFO mlflow.store.db.utils: Updating database tables
# 2025-11-28 19:20:56 INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# 2025-11-28 19:20:56 INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# 2025-11-28 19:20:56 INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# 2025-11-28 19:20:56 INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# <Experiment: artifact_location='/home/mukesh/Desktop/dspy/mlruns/2', creation_time=1764330026471, experiment_id='2', last_update_time=1764330026471, lifecycle_stage='active', name='Tracing Quickstart', tags={'mlflow.experimentKind': 'genai_development'}>

# %%
@mlflow.trace
def add(a, b):
  return a + b

# running the traced function triggers the UI display
add(1, 2)
# Out:
# 3

# %%
@mlflow.trace
def hello():
 return "Hello Mukesh"

# %%
hello()
# Out:
# 'Hello Mukesh'

# %%
@mlflow.trace
def hello(a, b):
 return a + b

# %%
hello("Mukesh", "raj")
# Out:
# 'Mukeshraj'

# %%
import mlflow

@mlflow.trace
def chat_completion(message: str, user_id: str, session_id: str):
    # Set these metadata keys to associate the trace to a user and session
    mlflow.update_current_trace(
        metadata={
            "mlflow.trace.user": user_id,
            "mlflow.trace.session": session_id,
        }
    )

    # Replace with your chat logic
    return "Your response here"

# Depending on your setup, user and session IDs can be passed to your
# server handler via the network request from your client applications,
# or derived from some other request context. 
user_id = "user-123"
session_id = "session-123"

chat_completion("Hello, how are you?", user_id, session_id)
# Out:
# 'Your response here'

# %%
# !uv pip install google-genai
# Out:
# Audited 1 package in 4ms

# %%
# !uv pip install python-dotenv
# Out:
# Audited 1 package in 3ms

# %%
# Import the necessary module
from dotenv import load_dotenv
import os

# Load environment variables from the .env file (if present)
load_dotenv()

# Access environment variables as if they came from the actual environment
api_key = os.getenv('API_KEY')

# %%
import os

import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("Tracing Quickstart")

import google.genai as genai

mlflow.gemini.autolog()

# Replace "GEMINI_API_KEY" with your API key
# client = genai.Client(api_key=api_key)

# Inputs and outputs of the API request will be logged in a trace
# client.models.generate_content(model="gemini/gemini-2.5-flash", contents="Explain quantum mechanics")

# %%
from google import genai

client = genai.Client(api_key=api_key)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Explain how AI works in a few words",
)

print(response.text)
# Out:
# AI analyzes data to learn patterns and make decisions or predictions.

# %%
client.models.generate_content(model="gemini-2.5-flash", contents="Explain quantum mechanics")
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""Quantum mechanics is a fundamental theory in physics that describes the physical properties of nature at the scale of atoms and subatomic particles. It's the framework we use to understand how the universe works at its most basic level, and it's incredibly successful, underpinning much of modern technology from lasers to transistors.
#
# However, it's also famously *weird* and counterintuitive, challenging our everyday understanding of reality.
#
# Here's an explanation broken down into its core ideas:
#
# ---
#
# ### The "Why": Where Classical Physics Failed
#
# Before quantum mechanics, we had "classical physics" (Newtonian mechanics, Maxwell's electromagnetism). This worked brilliantly for everyday objects and phenomena, but it started to fail spectacularly when applied to the very small:
#
# 1.  **Blackbody Radiation:** Classical physics couldn't explain why hot objects glowed the way they did, predicting an "ultraviolet catastrophe" where they should emit infinite energy.
# 2.  **Photoelectric Effect:** Light striking a metal could eject electrons, but only if it had a certain *frequency*, not just intensity. Classical physics couldn't explain this.
# 3.  **Atomic Stability:** According to classical physics, electrons orbiting an atomic nucleus should continuously radiate energy and spiral into the nucleus, making atoms unstable – which they clearly aren't.
# 4.  **Atomic Spectra:** When atoms emit light, they do so at specific, discrete colors (wavelengths), not a continuous rainbow. Classical physics had no explanation for these "spectral lines."
#
# These failures led to the development of quantum mechanics, starting in the early 20th century, to provide a new, more accurate description of reality at these tiny scales.
#
# ---
#
# ### The Core Ideas of Quantum Mechanics
#
# 1.  **Quantization:**
#     *   **Concept:** Energy, momentum, angular momentum, and other physical properties are not continuous but come in discrete packets, or "quanta."
#     *   **Analogy:** Imagine a ramp versus a staircase. In classical physics, you can stand anywhere on the ramp (continuous energy). In quantum mechanics, you can only stand on specific steps of the staircase (quantized energy levels).
#     *   **Origin:** Max Planck first introduced the idea that energy is quantized to explain blackbody radiation, with light energy packets called "photons."
#
# 2.  **Wave-Particle Duality:**
#     *   **Concept:** Everything in the quantum world (light, electrons, protons, etc.) exhibits both wave-like and particle-like properties, depending on how you observe it.
#     *   **Example:** Light, which we usually think of as a wave (electromagnetic radiation), behaves like a particle (photon) in phenomena like the photoelectric effect. Conversely, electrons, which we usually think of as particles, can diffract and interfere like waves (as shown in the double-slit experiment).
#     *   **Key Point:** You never observe both properties simultaneously. The act of measurement "forces" the entity to reveal either its wave or particle nature.
#
# 3.  **Superposition:**
#     *   **Concept:** Before being measured, a quantum particle can exist in multiple possible states *at the same time*. It's a combination of all its potential states.
#     *   **Analogy:** Imagine a spinning coin in the air. Before it lands, it's neither heads nor tails; it's in a superposition of both. Only when it lands (is measured) does it collapse into one definite state.
#     *   **Schrödinger's Cat:** This famous thought experiment illustrates the bizarre nature of superposition. A cat in a sealed box is simultaneously both alive AND dead until the box is opened and the cat's state is observed.
#
# 4.  **Measurement and Wave Function Collapse:**
#     *   **Concept:** The act of measuring a quantum system "collapses" its superposition, forcing it to pick one definite state out of all the possibilities.
#     *   **Wave Function:** The mathematical description of a quantum system is called its "wave function" (represented by the Greek letter Psi, $\Psi$). It doesn't tell us *what* the particle is doing, but rather the *probabilities* of finding it in various states if we were to measure it.
#     *   **The Problem:** The exact mechanism of wave function collapse and what constitutes a "measurement" (is it consciousness? interaction with a classical apparatus?) is still one of the deepest mysteries and sources of debate in quantum mechanics.
#
# 5.  **Uncertainty Principle (Heisenberg):**
#     *   **Concept:** There are certain pairs of properties (called "conjugate variables") that cannot be known simultaneously with arbitrary precision. The more precisely you know one, the less precisely you can know the other.
#     *   **Example:** You cannot simultaneously know both the exact position *and* the exact momentum (mass times velocity) of a particle. If you precisely measure its position, its momentum becomes very uncertain, and vice-versa.
#     *   **Key Point:** This isn't a limitation of our measuring instruments; it's a fundamental property of nature. The "fuzziness" is inherent to reality at the quantum level.
#
# 6.  **Quantum Entanglement:**
#     *   **Concept:** Two or more particles can become "entangled," meaning they are linked in such a way that they share a common fate, regardless of the distance between them.
#     *   **Spooky Action at a Distance:** If you measure a property of one entangled particle (e.g., its spin), you instantaneously know the corresponding property of the other entangled particle, even if it's light-years away. Einstein famously called this "spooky action at a distance" because it seemed to violate the speed limit of light (though no information can actually be sent faster than light).
#     *   **Verification:** Entanglement has been experimentally verified countless times and is a key resource for emerging technologies like quantum computing and quantum cryptography.
#
# ---
#
# ### Why It's Hard to Grasp
#
# *   **Counterintuitive:** Quantum rules simply don't match our everyday experience. We don't see cars in superposition or people instantly knowing each other's states across continents.
# *   **Probabilistic:** Unlike classical physics, which is deterministic (if you know the initial conditions, you can predict the future with certainty), quantum mechanics is fundamentally probabilistic. It tells us the *likelihood* of different outcomes.
# *   **Observer-Dependent:** The act of observation plays a crucial, active role in shaping reality at the quantum level, blurring the line between observer and observed.
#
# ---
#
# ### Impact and Applications
#
# Despite its weirdness, quantum mechanics is arguably the most successful scientific theory ever devised. It has been rigorously tested and confirmed by countless experiments. It's not just an abstract idea; it's the foundation for:
#
# *   **Modern Electronics:** Transistors, microchips, lasers, semiconductors, LED lights, MRI scanners.
# *   **Chemistry:** Understanding how atoms bond to form molecules.
# *   **Materials Science:** Designing new materials with specific properties.
# *   **Astrophysics:** Explaining the behavior of stars and galaxies.
# *   **Quantum Computing:** A nascent field that promises to harness quantum phenomena for incredibly powerful computation.
# *   **Quantum Cryptography:** Developing unhackable communication methods.
#
# ---
#
# **In essence, quantum mechanics is our most accurate and powerful description of the universe at its smallest scales. It reveals a reality that is fundamentally fuzzy, probabilistic, and interconnected, challenging our classical notions of objective reality and determinism. While its philosophical implications are still debated, its predictive power and technological impact are undeniable.**"""
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-flash',
#   response_id='faopafe0H8eVjuMPx9SvoQo',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=11>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=1597,
#     prompt_token_count=4,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=4
#       ),
#     ],
#     thoughts_token_count=1297,
#     total_token_count=2898
#   )
# )
